# %% [markdown]
# # Next Word Predictor Training on Colab
#
# This notebook allows you to train your Next Word Predictor model using Google Colab's GPU.

# %%
# 1. Clone your repository
# REPLACE THE URL BELOW WITH YOUR GITHUB REPOSITORY URL
# !git clone https://github.com/prashant311204/NextWordPredictor.git
# %cd NextWordPredictor

# %%
# 2. Install dependencies
# !pip install -r requirements.txt

# %%
# 3. Download data
# !python download_data.py

# %%
# 4. Preprocess data
# !python src/preprocess.py

# %%
# 5. Train model
# Ensure you have selected a GPU runtime in Colab (Runtime > Change runtime type > T4 GPU)
# !python src/train.py

# %%
# 6. Download trained model
import shutil
from google.colab import files

# Zip the models directory
shutil.make_archive('models', 'zip', 'models')

# Download the zip file
files.download('models.zip')
